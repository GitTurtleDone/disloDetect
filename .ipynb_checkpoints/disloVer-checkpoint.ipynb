# %%
# import sys
# print (sys.executable)
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
import csv
from ultralytics import YOLO
from PIL import Image, ImageDraw
from IPython.display import display
import matplotlib as matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = YOLO('./yolov8s.pt')

# %% [markdown]
# ### standard

# %%
model.train(model='./runs/detect/train63/weights/best.pt',\
            data='./verDislo2.yaml', \
            epochs=1000, batch=8,\
            imgsz = 640, patience = 1000,
            hide_labels = True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.43 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.9 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
# Do NOT change or remove this Cell
model.train(model='./yolov8s.pt',\
            data='./verDislo.yaml', \
            epochs=1000, batch=2,\
            imgsz = 640, patience = 300,
            hide_labels = True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.37 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.9 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %% [markdown]
# ### augmented

# %%
# .yolo8s.pt ./runs/detect/train55/weights/best.pt
model.train(model='./runs/detect/train58/weights/best.pt',\
            cfg = './ConfigYamlVersions/HSV.yaml', \
            data='./verDislo2.yaml', \
            epochs=1000, batch=8,\
            imgsz = 640, patience = 1000,
            hide_labels = True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.43 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.9 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
model.train(model='./yolov8s.pt',\
            cfg = './ConfigYamlVersions/Rotate.yaml', \
            data='./verDislo.yaml', \
            epochs=1000, batch=2,\
            imgsz = 640, patience = 1000,
            hide_labels = True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.20 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
model.train(model='./runs/detect/train34/weights/best.pt',\
            data='./verDislo2.yaml', \
            epochs=10000, batch=8,\
            imgsz = 640, patience = 10000,
            hide_labels = True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.30 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %% [markdown]
# ### post-training

# %%
model = YOLO('./runs/detect/train64/weights/best.pt')
metrics = model.val(data='./verDislo2.yaml')
print('mAP50:', metrics.box.map)
#print('mAP50-95:', metrics.box.map)
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.9 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDisloc
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:10<00:00,  5.00s/i
#                    all         21       1438      0.384      0.357      0.286      0.113
# Speed: 2.4ms preprocess, 9.1ms inference, 0.0ms loss, 5.2ms postprocess per image
# Results saved to runs/detect/val71
# mAP50: 0.11296443278416941

# %%
model = YOLO('./runs/detect/train64/weights/best.pt')
result = model.predict(source="./datasets/verDislocations2/test/images", conf = 0.15, save=True, save_txt = True, show_labels=False, show_conf=True, line_width = 1)
# Out:
# image 1/20 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations2/test/images/Ref04_Fig4a_Rot.jpg: 640x640 70 dislos, 83.9ms
# image 2/20 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations2/test/images/Ref06_Fig4e.jpg: 192x640 20 dislos, 42.5ms
# image 3/20 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations2/test/images/Ref07_Fig7.jpg: 192x640 101 dislos, 21.2ms
# image 4/20 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations2/test/images/Ref16_Fig11a_Ver.jpg: 576x640 94 dislos, 42.6ms
# image 5/20 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations2/test/images/Ref16_Fig15c_Ver.jpg: 480x640 215 dislos, 51.5ms
# ...

# %%
model = YOLO('./runs/detect/train42/weights/best.pt')
result = model.predict(source="./datasets/Dang2020APLM", conf = 0.15, save=True, save_txt = True, show_labels=False, show_conf=True, line_width = 1)
# Out:
# image 1/3 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/Dang2020APLM/Stack100.jpg: 640x544 18 dislos, 63.1ms
# image 2/3 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/Dang2020APLM/x0.jpg: 192x640 72 dislos, 8.2ms
# image 3/3 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/Dang2020APLM/x057.jpg: 224x640 111 dislos, 7.4ms
# Speed: 1.6ms preprocess, 26.2ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 640)
# Results saved to runs/detect/predict51
# 3 labels saved to runs/detect/predict51/labels

# %%
#default conf is 0.25
model = YOLO('./runs/detect/train29/weights/best.pt')
result = model.predict(source="./datasets/verDislocations1/test/images", save=True, save_txt = True, show_labels=False, show_conf=True, line_width = 1)
# Out:
# image 1/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref04_Fig4a_Rot.jpg: 640x640 51 dislos, 52.6ms
# image 2/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref06_Fig4e.jpg: 192x640 6 dislos, 46.4ms
# image 3/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref07_Fig7.jpg: 192x640 34 dislos, 20.6ms
# image 4/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/wb190524_cropped_rotated.jpg: 640x640 19 dislos, 11.3ms
# Speed: 2.4ms preprocess, 32.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict12
# 4 labels saved to runs/detect/predict12/labels

# %%
#!!!Do NOT remove this cell!!!!
model = YOLO('./runs/detect/train13/weights/best.pt')
result = model.predict(source="./datasets/verDislocations1/test/images", conf = 0.1, save=True, save_txt = True, show_labels=False, show_conf=True, line_width = 1)
# Out:
# image 1/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref04_Fig4a_Rot.jpg: 640x640 200 dislos, 97.8ms
# image 2/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref06_Fig4e.jpg: 192x640 22 dislos, 8.3ms
# image 3/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref07_Fig7.jpg: 192x640 177 dislos, 6.9ms
# image 4/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/wb190524_cropped_rotated.jpg: 640x640 50 dislos, 11.6ms
# Speed: 1.8ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 4 labels saved to runs/detect/predict3/labels

# %%
#!!!Do NOT remove this cell!!!!
model = YOLO('./runs/detect/train13/weights/best.pt')
result = model.predict(source="./datasets/verDislocations1/test/images", conf = 0.2, save=True, save_txt = True, show_labels=False, show_conf=True, line_width = 1)
# Out:
# image 1/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref04_Fig4a_Rot.jpg: 640x640 70 dislos, 98.1ms
# image 2/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref06_Fig4e.jpg: 192x640 15 dislos, 7.4ms
# image 3/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref07_Fig7.jpg: 192x640 64 dislos, 6.1ms
# image 4/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/wb190524_cropped_rotated.jpg: 640x640 17 dislos, 11.2ms
# Speed: 1.8ms preprocess, 30.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
# 4 labels saved to runs/detect/predict4/labels

# %%
#!!!Do NOT remove this cell!!!!
##Script that has been run to provide the data for the abstract sent to IWGO2024
model = YOLO('./runs/detect/train13/weights/best.pt')
result = model.predict(source="./datasets/verDislocations1/test/images", conf = 0.15, save=True, save_txt = True, show_labels=False, show_conf=True, line_width = 1)
# Out:
# image 1/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref04_Fig4a_Rot.jpg: 640x640 123 dislos, 105.9ms
# image 2/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref06_Fig4e.jpg: 192x640 17 dislos, 7.9ms
# image 3/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/Ref07_Fig7.jpg: 192x640 109 dislos, 6.1ms
# image 4/4 /mnt/c/Users/gtd19/OneDrive - University of Canterbury/NZ2208/Programming/AI/MyProjects/dislocations/datasets/verDislocations1/test/images/wb190524_cropped_rotated.jpg: 640x640 25 dislos, 17.8ms
# Speed: 1.9ms preprocess, 34.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 4 labels saved to runs/detect/predict5/labels

# %% [markdown]
# # Processing

# %%
def readBB(filename, dataOrg = 'row'): # returns coordinates of bounding boxes stored in a .txt file 
  # if dataOrg = 'row' each row will have class and coordinates of a bounding box
  # if dataOrg = 'col' each columns will store class and coordinates of all corresponding bounding boxes
  try:
    with open(filename, 'r') as file:
      data = []
      for line in file:
        # Split the line into a list of numbers (as strings)
        numbers_as_str = line.strip().split()
        # Check if there are exactly five numbers
        if len(numbers_as_str) != 5:
          raise ValueError(f"Expected 5 numbers per row in {filename}, found {len(numbers_as_str)} in line: {line}")
        # Convert strings to floating-point numbers
        data.append([float(num) for num in numbers_as_str])
    if dataOrg == 'row':
        return data
    else: 
        # Organize data into columns using list comprehension
        columns = [[row[i] for row in data] for i in range(5)]
        return columns

  except FileNotFoundError:
    print(f"Error: File '{filename}' not found.")
    return None
  except ValueError as e:
    print(e)
    return None
def getTxtFiles(folderPath):
    filenames = []
    for filename in os.listdir(folderPath):
        print(filename)
        if filename.endswith(".txt"):
            filenames.append(filename)
    return filenames
def drawBB(image, coordinates, convertFromXYWHN = True):
    """
    Draws a bounding box on an image given coordinates.

    Args:
      image (numpy.ndarray): The image as a NumPy array.
      coordinates (list): A list containing four elements representing
                          top-left x, top-left y, bottom-right x, and bottom-right y
                          coordinates of the bounding box.
    """
    if convertFromXYWHN:
        xTL = coordinates[0] - coordinates[2]/2
        xBR = coordinates[0] + coordinates[2]/2
        yTL = coordinates[1] - coordinates[3]/2
        yBR = coordinates[1] + coordinates[3]/2
    else:
        (xTL, yTL, xBR, yBR) = coordinates
    xTL = int(xTL * image.size[0])
    xBR = int(xBR * image.size[0])
    yTL = int(yTL * image.size[1])
    yBR = int(yBR * image.size[1])
    bbox = (xTL, yTL, xBR, yBR)
    draw = ImageDraw.Draw(image)
    draw.rectangle(bbox, outline = 'red', width = 2)  # Green box with thickness 2
def sumBBHeights(labelFilePath):
    dataBB = readBB(labelFilePath, dataOrg = 'col')
    #print(dataBB[4])
    return (sum (dataBB[4]))
def getAllSums(filePaths):
    #fileNames = getTxtFiles(labelFolderPath)
    return ([sumBBHeights(filePath) for filePath in filePaths])

# %%
labelFolderPath = './ProcessingData/verDislo2Test/labels/'
fileNames = getTxtFiles(labelFolderPath)
filePaths = [(labelFolderPath + fileName) for fileName in fileNames]
testDislo2AllSums = getAllSums(filePaths)
print(testDislo2AllSums)
# Out:
# Ref04_Fig4a_Rot.txt
# Ref06_Fig4e.txt
# Ref07_Fig7.txt
# Ref16_Fig11a_Ver.txt
# Ref16_Fig15c_Ver.txt
# Ref20_Fig1b.txt
# Ref21_Fig2a.txt
# Ref27_Fig7c.txt
# Ref28_Fig4.txt
# Ref30_Fig2a.txt
# wb190419_170121N10_WEEK-3.txt
# wb190419_170121N10_WEEK-3_cropped.txt
# wb190426_170121N12_100nmStackOutBFDFWB_WeakBeam.txt
# wb190426_170121N12_100nmStackOutBFDFWB_WeakBeam_cropped.txt
# wb190513_170121N6OutBigNew_WB.txt
# wb190513_170121N6OutBigNew_WB2.txt
# wb190513_170121N6OutBigNew_WB2_cropped.txt
# wb190513_170121N6OutBigNew_WB_cropped.txt
# wb210421_GOonPatGONormalBig_WBDF6.txt
# wb210421_GOonPatGONormalBig_WBDF6_cropped.txt
# [3.3104950000000013, 6.4019, 35.385837, 12.787335, 20.614268, 1.8270629999999999, 11.407510999999996, 3.3472519999999997, 5.324599000000001, 56.800183000000004, 6.820749999999999, 10.875775, 12.420414000000008, 15.931408000000001, 8.441449000000004, 8.499017, 35.845962999999976, 37.170289000000004, 3.6317170000000005, 4.350357]

# %%
labelFolderPath = './ProcessingData/predict66/labels/'
fileNames = getTxtFiles(labelFolderPath)
filePaths = [(labelFolderPath + fileName) for fileName in fileNames]
preAllSums = getAllSums(filePaths)
print(preAllSums)
# Out:
# Ref04_Fig4a_Rot.txt
# Ref06_Fig4e.txt
# Ref07_Fig7.txt
# Ref16_Fig11a_Ver.txt
# Ref16_Fig15c_Ver.txt
# Ref20_Fig1b.txt
# Ref21_Fig2a.txt
# Ref27_Fig7c.txt
# Ref28_Fig4.txt
# Ref30_Fig2a.txt
# wb190419_170121N10_WEEK-3.txt
# wb190419_170121N10_WEEK-3_cropped.txt
# wb190426_170121N12_100nmStackOutBFDFWB_WeakBeam.txt
# wb190426_170121N12_100nmStackOutBFDFWB_WeakBeam_cropped.txt
# wb190513_170121N6OutBigNew_WB.txt
# wb190513_170121N6OutBigNew_WB2.txt
# wb190513_170121N6OutBigNew_WB2_cropped.txt
# wb190513_170121N6OutBigNew_WB_cropped.txt
# wb210421_GOonPatGONormalBig_WBDF6.txt
# wb210421_GOonPatGONormalBig_WBDF6_cropped.txt
# [6.263223000000002, 11.638797000000002, 51.436106000000024, 19.564132199999992, 28.47959179999999, 3.8268361999999994, 15.520384100000006, 7.241370399999999, 11.200628199999995, 101.73611849999993, 8.7635335, 16.2205901, 22.807603799999992, 15.527598099999999, 19.330396000000007, 18.2948114, 40.19231089999999, 54.129936, 7.754035000000001, 7.7284918000000005]

# %%
arrImageNum = range(1,21)
testDislo2AllSums = np.array(testDislo2AllSums)
preAllSums = np.array(preAllSums)
err = (preAllSums-testDislo2AllSums)/testDislo2AllSums*100
csvFilePath = labelFolderPath + "pre66AllSums.csv" 
with open(csvFilePath, "w", newline="") as csvfile:
  # Create a csv writer object
  writer = csv.writer(csvfile)
  # Combine data using zip and write as rows
  writer.writerow(["File name","Image number", "Human-labeled", "Predicted", "Error %"])
  writer.writerows(zip(fileNames, arrImageNum, testDislo2AllSums, preAllSums, err))
fig, ax = plt.subplots(1,2)
line1, = ax[0].plot(arrImageNum, testDislo2AllSums, marker = 's', markersize=10, markerfacecolor='none', markeredgewidth=1, markeredgecolor='black', linestyle = 'None', label = 'Human labeled 2nd DS')
line2, = ax[0].plot(arrImageNum, preAllSums, marker = 'o', markersize=10, markerfacecolor='none', markeredgewidth=1, markeredgecolor='red', linestyle = 'None', label = 'predicted by 2nd model')
line3, = ax[1].plot(arrImageNum, err, marker = '^', markersize=10, markerfacecolor='none', markeredgewidth=1, markeredgecolor='green', linestyle = 'None', label = 'predicted by 2nd model')

# %% [markdown]
# # MLOPs

# %%
model = YOLO('./runs/train35/weights/best.pt')
model.export(format = 'onnx')
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.9 torch-2.0.0+cu117 CPU (Intel Core(TM) i7-9700 3.00GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from 'runs/train35/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (21.5 MB)
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: export success ✅ 0.7s, saved as 'runs/train35/weights/best.onnx' (42.6 MB)
#
# Export complete (2.7s)
# Results saved to /home/giang/Programming/AI/disloDetect/runs/train35/weights
# Predict:         yolo predict task=detect model=runs/train35/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/train35/weights/best.onnx imgsz=640 data=./verDislo2.yaml
# ...

# %% [markdown]
# # unsorted

# %%
fig, ax = plt.subplots(1,2)
line1, = ax[0].plot(arrImageNum, testDislo2AllSums, marker = 's', markersize=10, markerfacecolor='none', markeredgewidth=1, markeredgecolor='black', linestyle = 'None', label = 'Human labeled 2nd DS')
line2, = ax[0].plot(arrImageNum, preAllSums, marker = 'o', markersize=10, markerfacecolor='none', markeredgewidth=1, markeredgecolor='red', linestyle = 'None', label = 'predicted by 2nd model')
line3, = ax[1].plot(arrImageNum, err, marker = '^', markersize=10, markerfacecolor='none', markeredgewidth=1, markeredgecolor='green', linestyle = 'None', label = 'predicted by 2nd model')
# plt.tight_layout()
# plt.show()

# %%
labelFolderPath = './ProcessingData/verDislo2Test/labels/'
fileNames = getTxtFiles(labelFolderPath)
filePaths = [(labelFolderPath + fileName) for fileName in fileNames]
testDislo2AllSums = getAllSums(filePaths)
print(testDislo2AllSums)
# Out:
# Ref04_Fig4a_Rot.txt
# Ref06_Fig4e.txt
# Ref07_Fig7.txt
# Ref16_Fig11a_Ver.txt
# Ref16_Fig15c_Ver.txt
# Ref20_Fig1b.txt
# Ref21_Fig2a.txt
# Ref27_Fig7c.txt
# Ref28_Fig4.txt
# Ref30_Fig2a.txt
# wb190419_170121N10_WEEK-3.txt
# wb190419_170121N10_WEEK-3_cropped.txt
# wb190426_170121N12_100nmStackOutBFDFWB_WeakBeam.txt
# wb190426_170121N12_100nmStackOutBFDFWB_WeakBeam_cropped.txt
# wb190513_170121N6OutBigNew_WB.txt
# wb190513_170121N6OutBigNew_WB2.txt
# wb190513_170121N6OutBigNew_WB2_cropped.txt
# wb190513_170121N6OutBigNew_WB_cropped.txt
# wb210421_GOonPatGONormalBig_WBDF6.txt
# wb210421_GOonPatGONormalBig_WBDF6_cropped.txt
# [3.3104950000000013, 6.4019, 35.385837, 12.787335, 20.614268, 1.8270629999999999, 11.407510999999996, 3.3472519999999997, 5.324599000000001, 56.800183000000004, 6.820749999999999, 10.875775, 12.420414000000008, 15.931408000000001, 8.441449000000004, 8.499017, 35.845962999999976, 37.170289000000004, 3.6317170000000005, 4.350357]

# %%
folderPath = './ProcessingData/predict53/labels'
fileNames = getTxtFiles(folderPath)
# Out:
# Ref04_Fig4a_Rot.txt
# Ref06_Fig4e.txt
# Ref07_Fig7.txt
# wb190524_cropped_rotated.txt

# %%
filePath = folderPath + '/' + fileNames[0]
data = readBB(filePath)
#print(data)

# %%
labelPath = imageFilePath.replace( ".jpg", ".txt")
labelPath = labelPath.replace("images", "labels")
print (labelPath, ": ", sumBBHeights(labelPath))
# Out:
# [0.025792, 0.025792, 0.03714, 0.031982, 0.079439, 0.097493, 0.072733, 0.052099, 0.053131, 0.066027, 0.037656, 0.113035, 0.036333, 0.121513, 0.119495, 0.091639, 0.065399, 0.050866, 0.073877, 0.130394, 0.076703, 0.029066, 0.082758, 0.138468, 0.108595, 0.083565, 0.101732, 0.092447, 0.075088, 0.059747, 0.106173, 0.116265, 0.092851, 0.094465, 0.05127, 0.039159, 0.108998, 0.044407, 0.039159, 0.08841, 0.084373, 0.022607, 0.033507]
# ./datasets/verDislocations1/test/labels/Ref04_Fig4a_Rot.txt :  3.151648000000001

# %%
imageFolderPath = './datasets/verDislocations1/test/images/'
imageFilePath = imageFolderPath + 'Ref04_Fig4a_Rot.jpg'

# Load the image
image = Image.open(imageFilePath)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=382x379>

# %%
# Define bounding box coordinates (replace with your actual values)
coordinates = [data[2][i] for i in [1,2,3,4]]
# # Draw the bounding box
drawBB(image, coordinates)

# Display the modified image in Jupyter Notebook
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=382x379>

# %%
labelFolderPath = './ProcessingData/predict23/labels'
fileNames = getTxtFiles(labelFolderPath)
filePaths = [(labelFolderPath + "/" + fileName) for fileName in fileNames]
pre23AllSums = getAllSums(filePaths)
print(pre23AllSums)
# Out:
# Ref04_Fig4a_Rot.txt
# Ref06_Fig4e.txt
# Ref07_Fig7.txt
# wb190524_cropped_rotated.txt
# [6.0117601999999986, 7.774903999999999, 53.84079049999999, 4.3426442]

# %%
labelFolderPath = './ProcessingData/predict24/labels'
fileNames = getTxtFiles(labelFolderPath)
filePaths = [(labelFolderPath + "/" + fileName) for fileName in fileNames]
pre24AllSums = getAllSums(filePaths)
print(pre24AllSums)
# Out:
# Ref04_Fig4a_Rot.txt
# Ref06_Fig4e.txt
# Ref07_Fig7.txt
# Ref16_Fig11a_Ver.txt
# Ref16_Fig15c_Ver.txt
# Ref20_Fig1b.txt
# Ref21_Fig2a.txt
# Ref27_Fig7c.txt
# Ref28_Fig4.txt
# Ref30_Fig2a.txt
# wb190524_cropped_rotated.txt
# [6.0117601999999986, 7.774903999999999, 53.84079049999999, 19.870924000000006, 27.752073100000008, 2.595224400000001, 15.205954399999987, 7.535783500000001, 8.845527599999999, 90.08202759999999, 4.3426442]

# %%
labelFolderPath = './ProcessingData/verDislo1Test/labels'
fileNames = getTxtFiles(labelFolderPath)
filePaths = [(labelFolderPath + "/" + fileName) for fileName in fileNames]
testDislo1AllSums = getAllSums(filePaths)
print(testDislo1AllSums)
# Out:
# Ref04_Fig4a_Rot.txt
# Ref06_Fig4e.txt
# Ref07_Fig7.txt
# wb190524_cropped_rotated.txt
# [3.151648000000001, 5.858785, 30.295029000000007, 6.356833000000001]

# %%
labelFolderPath = './ProcessingData/predict25/labels'
fileNames = getTxtFiles(labelFolderPath)
filePaths = [(labelFolderPath + "/" + fileName) for fileName in fileNames]
pre25AllSums = np.array(getAllSums(filePaths))
bar = 2e-5 

barIm = 1.4
W1 = 2.55/barIm*bar
W2 = 8.85/barIm*bar
W3 = 8.55/barIm*bar
W = np.array([W1, W2, W3])
t = np.array([1.41e-5, 1.24e-5, 1.77e-5])
disloDens = pre25AllSums/W/t/1.5
print(disloDens)
# Out:
# Stack100.txt
# x0.txt
# x057.txt
# [ 1.9377e+10  2.0793e+10  1.6618e+10]

# %%
#Fig27_Fig7c
bar = 2e-5 # cm
dxBarIm = 0.48 # cm
dyBarIm = 0.17 # cm
barIm = (dxBarIm**2+dyBarIm**2)**0.5 #cm
HpIm = 7.25 #cm
Hp = HpIm/barIm*bar #cm
t = 1e-5 # cm
dxFilmIm = 5.34 #cm
dyFilmIm = 1.86 #cm
filmHeight = (dxFilmIm**2 + dyFilmIm**2)**0.5 / barIm * bar #in cm 
SFilm = (dxFilmIm**2 + dyFilmIm**2)/barIm**2*bar**2
print(pre24AllSums[7]*filmHeight/SFilm/t) # in cm-2
print(filmHeight)
print(SFilm)
print(pre24AllSums[7])
# Out:
# 3393071729.9320397
# 0.00022209325648859585
# 4.932541457770922e-08
# 7.535783500000001

# %%
# import cv2
# from IPython.display import Image
# imageFolderPath = './datasets/verDislocations1/test/images/'
# imageFilePath = imageFolderPath + 'Ref06_Fig4e.jpg'
# im = cv2.imread(imageFilePath)
# cv2.imshow("Test", im)
# cv2.waitKey(0)
# cv2.destroyWindow("Test")
# display(Image(im)) doesn't work
